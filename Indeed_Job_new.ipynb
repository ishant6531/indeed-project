# %%
# Loading  Necessary  library 

from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
from time import sleep
import warnings
warnings.filterwarnings('ignore')
import time
import string

driver=webdriver.Chrome(r"C:\Users\thunderbolt\sof\chromedriver.exe")

Job_Title = []
Company = []
Rating = []
Location = []
Short_Description = []
Days_Posted = []
Salary = []
Brief_Description = []
crawl_timestamp = []
crawl_date = []

# %%
from datetime import date

# %%
# Getting   all the Data Science  job  details data.


for i in range(0,50,10):

    driver.get("https://in.indeed.com/jobs?q=Data+Scientist+&l=Gurgaon%2C+Haryana&start="+ str(i))

    time.sleep(5)

    all_jobs = driver.find_elements_by_class_name('result')

    for job in all_jobs:
    
        result_html= job.get_attribute('innerHTML')
        soup = BeautifulSoup(result_html,'html.parser')
        
        
        time.sleep(1)
        
        task1 = time.gmtime()
        crawl_timestamp.append(time.strftime("%Y-%m-%d %H:%M:%S", task1))
        
        
        today = date.today()    
        task2 = today.strftime("%d %B %Y")
        crawl_date.append(task2) 
        
        
    
    
        try:
            title = soup.find("a" ,class_="jobtitle").text.replace('\n',' ')
            Job_Title.append(title)
        except:
            Job_Title.append('---')
        
    
    
        try:
            company = soup.find("span" ,class_="company").text.replace('\n',' ')
            Company.append(company)
        except:
            Company.append('---')
        

        try:
            rating = soup.find("span" ,class_="ratingsContent").text.replace('\n',' ')
            Rating.append(rating)
        except:
            Rating.append('---')
        
        try:
            location = soup.find("span" ,class_="location accessible-contrast-color-location").text.replace('\n',' ')
            Location.append(location)
        except:
            Location.append('---')
        
        
        try:
            salary = soup.find("span" ,class_="salaryText").text.replace('\n',' ')
            Salary.append(salary)
        except:
            Salary.append('Not Mentioned')
        

        
        try:
            days_posted = soup.find("span" ,class_="date").text.replace('\n',' ')
            Days_Posted.append(days_posted)
        except:
            Days_Posted.append('---')
        
  
        
        sum_div = job.find_elements_by_class_name("summary")[0]
        sum_div.click()
        
        time.sleep(5)
        
        
        try:
            job_desc = driver.find_element_by_id("vjs-desc").text.replace('\n',' ')
            Brief_Description.append(job_desc)
        except:
            Brief_Description.append('----')

# %%
# Getting length of all variables.
print(len(crawl_timestamp),len(crawl_date),len(crawl_date),len(Job_Title),len(Company),len(Rating),len(Location),len(Salary),len(Days_Posted),len(Brief_Description))
# Out:
# 63 63 63 63 63 63 63 63 63 63

# %%
# Getting Final Data
Data_Science =pd.DataFrame({ 'Job Title' : Job_Title ,'Company Name' : Company,'Location Of Job' : Location ,' Salary' :Salary , 'Rating' : Rating ,   'Days Posted' : Days_Posted ,'Crawl Timestamp': crawl_timestamp , ' Date Stamp' : crawl_date ,'Job Description' : Brief_Description  })
Data_Science
# Out:
#                                             Job Title  \
# 0                                      Data Scientist
# 1                            Junior Data Scientist/ta
# 2                                      Data Scientist
# 3                                      Data Scientist
# 4    CN - Strategy - MC - T&O - OA Data Scientist ...
# ..                                                ...
# 58                                       Lead Analyst
# 59         Machine Learning Engineer - Senior Advisor
# 60                       Associate Analytics Director
# 61         Machine Learning Engineer - Senior Advisor
# 62                              Sr. Analytics Manager
#
#                          Company Name   Location Of Job  \
# 0    Applicate IT Solutions Pvt. Ltd.  Gurgaon, Haryana
# 1                      WSD Consultant  Gurgaon, Haryana
# 2                  Diverse Lynx India  Gurgaon, Haryana
# 3                           Donaldson  Gurgaon, Haryana
# 4                           Accenture  Gurgaon, Haryana
# ..                                ...               ...
# 58                      Junglee Games  Gurgaon, Haryana
# 59                  Dell Technologies               ---
# 60                            Essence  Gurgaon, Haryana
# 61                  Dell Technologies               ---
# 62                            Essence  Gurgaon, Haryana
#
#                              Salary     Rating   Days Posted  \
# 0      ₹3,00,000 - ₹5,00,000 a year        ---   21 days ago
# 1     ₹7,00,000 - ₹15,00,000 a year        ---   21 days ago
# 2                     Not Mentioned   4.8              Today
# 3                     Not Mentioned        ---    6 days ago
# 4                     Not Mentioned   4.0          1 day ago
# ..                              ...        ...           ...
# 58   ₹30,00,000 - ₹50,00,000 a year   4.7       30+ days ago
# 59                    Not Mentioned   4.0        14 days ago
# 60                    Not Mentioned        ---  30+ days ago
# 61                    Not Mentioned   4.0        14 days ago
# 62                    Not Mentioned        ---  30+ days ago
#
#         Crawl Timestamp        Date Stamp  \
# 0   2020-12-30 08:47:11  30 December 2020
# 1   2020-12-30 08:47:18  30 December 2020
# 2   2020-12-30 08:47:24  30 December 2020
# 3   2020-12-30 08:47:31  30 December 2020
# 4   2020-12-30 08:47:37  30 December 2020
# ..                  ...               ...
# 58  2020-12-30 08:53:52  30 December 2020
# 59  2020-12-30 08:53:58  30 December 2020
# 60  2020-12-30 08:54:13  30 December 2020
# 61  2020-12-30 08:54:20  30 December 2020
# 62  2020-12-30 08:54:26  30 December 2020
#
#                                       Job Description
# 0   Understand business domain and solve business ...
# 1   Gurgaon, Bangalore, Mumbai, Pune, Chennai, Hyd...
# 2   Job description Responsibilities for Data Scie...
# 3   Donaldson is committed to solving the world’ s...
# 4   Job Description About Accenture: Accenture is ...
# ..                                                ...
# 58  As our Lead Analyst, you will gather, analyze,...
# 59  Senior Advisor, Machine Learning Engineer Deci...
# 60  About Essence  Essence, part of GroupM, is a g...
# 61  Senior Advisor, Machine Learning Engineer Deci...
# 62  About Essence Essence, part of GroupM, is a gl...
#
# [63 rows x 9 columns]

# %% [markdown]
# # Saving the file

# %%
 Data_Science.to_csv("Data_Science5.csv")

# %% [markdown]
# # ***End Of Document* **
